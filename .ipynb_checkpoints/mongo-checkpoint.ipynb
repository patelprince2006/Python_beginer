# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017")

db = client["collagedb1"]
collection = db["students"]

collection.insert_one({"name": "Alice", "age": 22, "major": "Computer Science"})
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[2], line 7
#       4 db = client["collagedb1"]
#       5 collection = db["students"]
# ----> 7 collection.insert_one({"name": "Alice", "age": 22, "major": "Computer Science"})
#
# File E:\Anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
# ...

# %%
#projection
for doc in collection.find({'name':'Dhairya'},{});
   print(doc)

#for doc in collection.find({filter},{data which retrive}) 
#for doc in collection.find({where},{attribute})

for doc in collection.find().limit(2)
  print(doc)

for doc in collection.find().skip(2)
  print(doc)
    
for doc in collection.find({'age':{'gt':25}})   #gt, gte , lte,lt
  print(doc)

for doc in collection.find({'age':{'in':[22,25]})   # not in => nin
  print(doc)

#update
collection.update_one({'age':26},{'$set':{''}})
